# %% [markdown]
# # Motivation
#
# A major
#
# If you've never listened to Queen before, chances are you don't know where to start. Bands like Queen have touched upon myriad topics throughout their long, successful careers. It would be great to
#
#
#
#
# [Nightwish](https://nightwish.com/) is a symphonic power metal band from Finland and one of the biggest names in the European metal scene. Since 1996, they have released 9 studio albums and numerous singles, EP's, and live albums. The most recent album *Human. :II: Nature.* just came out in April 2020. Throughout their career, Nightwish has explored a wide variety of themes, ranging from personal topics to science and nature. As a Nightwish fan and aspiring data scientist, I thought it might be interesting to look at how the lyrical themes of Nightwish have evolved over the past 24 years.

# %% [markdown]
# Resources
# 1. https://www.kaggle.com/ykhorramz/lda-and-t-sne-interactive-visualization
# 2. https://towardsdatascience.com/end-to-end-topic-modeling-in-python-latent-dirichlet-allocation-lda-35ce4ed6b3e0
# 3. https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24
# 4. https://news.codecademy.com/taylor-swift-lyrics-machine-learning/
# 5. https://honingds.com/blog/topic-modeling-latent-dirichlet-allocation-lda/

# %% [markdown]
# # Data Preparation

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from collections import Counter
import spacy
import en_core_web_lg
import gensim
from gensim import corpora, models
from gensim.models import word2vec, CoherenceModel
from wordcloud import WordCloud
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.cluster import DBSCAN, AgglomerativeClustering, KMeans
import hdbscan
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
import clean
import word_2dviz

pd.options.mode.chained_assignment = None
import pyLDAvis.gensim

pyLDAvis.enable_notebook()

import warnings

warnings.filterwarnings("ignore")

# %load_ext lab_black

# %% [markdown]
# ## Load data
# I have already cleaned data.

# %%
# Read from CSV
df = pd.read_csv("nightwish_lyrics.csv")

# Drop rows that no longer have lyrics
df_clean = df.dropna()

# %% [markdown]
# ## Extract information

# %% [markdown]
# ### Aggregate by song
# However, the data is not at the right level of granularity.

# %%
# Aggregate lyrics by song
df_song = (
    df_clean.groupby(["track_title"])["lyric_lemma"]
    .apply(lambda x: " ".join(x))
    .reset_index()
)

# %%
#  JOIN df_song with df_clean for album title and year
df_merged = df_song.merge(
    df_clean[["track_title", "album_title", "year"]],
    on="track_title",
    validate="one_to_many",
)

# Drop duplicated rows
df_merged.drop_duplicates(inplace=True)

# Reset index
df_merged.reset_index(inplace=True)

# %% [markdown]
# ### Studio album only

# %%
# List of studio albumns by Nightwish
studio_albums = [
    "Angels Fall First",
    "Oceanborn",
    "Wishmaster",
    "Century Child",
    "Once",
    "Dark Passion Play",
    "Imaginaerum",
    "Hvman. :||: Natvre.",
]

# Only keep in-album songs
df_merged = df_merged.loc[df_merged["album_title"].isin(studio_albums)]

# Reset index
df_merged.reset_index(inplace=True)

# Drop extra columns
df_merged.drop(["level_0", "index"], axis=1, inplace=True)

# %% [markdown]
# ## NLP preprocessing

# %% [markdown]
# ### Further stopword removal

# %%
# Manually filter out more stopwords
filter = ["s", "oh", "ah", "o", "e", "ee", "ieee", "let"]

lyrics_clean = []

for lyric in df_merged["lyric_lemma"]:
    lyric_list_clean = [word for word in lyric.split() if word not in filter]
    lyric_clean = " ".join(lyric_list_clean)
    lyrics_clean.append(lyric_clean)

df_merged["lyric_lemma"] = lyrics_clean

# %% [markdown]
# ### Tokenization

# %%
# Tokenize words
lyrics = df_merged["lyric_lemma"].tolist()
lyrics = [i for i in lyrics if i]  # Remove empty strings
tokens = [lyric.split() for lyric in lyrics]

# %% [markdown]
# ### Bag of words

# %%
# Create a "bag of words"
dictionary = corpora.Dictionary(tokens)
dictionary.filter_extremes(
    no_below=10, no_above=0.5
)  # Filter out words that are too rare or too common
corpus_bow = [dictionary.doc2bow(token) for token in tokens]

# %% [markdown]
# ### TF-IDF

# %%
# Create TF-IDF
tfidf = models.TfidfModel(corpus_bow)
corpus_tfidf = tfidf[corpus_bow]

# %% [markdown]
# ### Save dictionary and corpora

# %%
pickle.dump(corpus_bow, open("corpus_bow.pkl", "wb"))
pickle.dump(corpus_tfidf, open("corpus_tfidf.pkl", "wb"))
dictionary.save("dictionary.gensim")

# %% [markdown]
# ### Word embeddings

# %% [markdown]
# #### For each song

# %%
# Load pre-trained English model
nlp = en_core_web_lg.load()

# %%
# Average vectors for each song
X_song = np.array(
    [nlp(song["lyric_lemma"]).vector for idx, song in df_merged.iterrows()]
)

# Center the vectors
vec_mean = X_song.mean(axis=0)
X_song = pd.DataFrame([vec - vec_mean for vec in X_song])

# %%
# Standardization
song_scaler = StandardScaler()
X_song_std = song_scaler.fit_transform(X_song)

# %% [markdown]
# #### For each word

# %%
# Train Word2Vec model
model = word2vec.Word2Vec(tokens, min_count=10)  # Words should appear at least 10 times

# Save model
model.save("model.bin")

# Retrieve vectors
X_vocab = model[model.wv.vocab]

# %%
# Standardization
vocab_scaler = StandardScaler()
X_vocab_std = vocab_scaler.fit_transform(X_vocab)

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Word cloud

# %%
# Store all tokens in a single string
tokens_flat = [item for items in tokens for item in items]
comment_words = " ".join(tokens_flat) + " "

# %%
# Generate a word cloud
wordcloud = WordCloud(width=800, height=800, background_color="white").generate(
    comment_words
)

plt.figure(figsize=(6, 6), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# ### Word frequencies

# %%
# Count each word's frequency
dict_freq = Counter(tokens_flat)
df_freq = pd.DataFrame.from_dict(dict_freq, orient="index").reset_index()
df_freq = df_freq.rename(columns={"index": "word", 0: "count"})

# %%
# Plot frequencies of top 15 words
top10 = df_freq.sort_values(by=["count"], ascending=False)[0:10]

sns.barplot(x="word", y="count", data=top10)
plt.title("Top 10 Words in Nightwish Songs")
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Word clustering

# %% [markdown]
# ## KNN

# %%
# Extract 2 principle components
X_song_pca = PCA(n_components=2).fit_transform(X_song_std)

# %%
# Elbow method: Plot sse against k
sse = []
list_k = list(range(1, 10))

for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(X_song_pca)
    sse.append(km.inertia_)

plt.figure(figsize=(6, 6))
plt.plot(list_k, sse, "-o")
plt.xlabel(r"Number of clusters (K)")
plt.ylabel("Sum of squared distance")
plt.show()

# %%
# Create KMeans object using k=4
kmeans = KMeans(n_clusters=3, random_state=123)

# Fit model
y_kmeans = kmeans.fit_predict(X_song_pca)

# Visualize results
plt.scatter(X_song_pca[:, 0], X_song_pca[:, 1], c=y_kmeans, s=50, cmap="viridis")
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c="black", s=200, alpha=0.5)
plt.title("K-Means Clustering")
plt.show()

# Evaluate results
kmeans_silhouette = round(float(metrics.silhouette_score(X_song_pca, y_kmeans)), 2)
print(f"The silhouette score of k-means using 3 clusters is {kmeans_silhouette}.")
# Out:
# The silhouette score of k-means using 3 clusters is 0.36.

# %% [markdown]
# ## Hierarchical clustering

# %%
# Try different linkage methods
links = ["average", "complete", "ward"]

for link in links:

    # Create object using each method
    hier_model = AgglomerativeClustering(linkage=link, affinity="euclidean")

    # Fit model
    y_hier = hier_model.fit_predict(X_song_pca)

    # Visualize results
    plt.scatter(X_song_pca[:, 0], X_song_pca[:, 1], c=y_hier, s=50, cmap="viridis")
    plt.title(f"Hierachical Clustering ({link.capitalize()})")
    plt.show()

    # Evaluate results
    hier_silhouette = round(float(metrics.silhouette_score(X_song_pca, y_hier)), 2)
    print(
        f"The silhouette score of hierarchical clustering ({link}) is {hier_silhouette}."
    )
# Out:
# The silhouette score of hierarchical clustering (average) is 0.44.
# The silhouette score of hierarchical clustering (complete) is 0.23.
# The silhouette score of hierarchical clustering (ward) is 0.36.

# %% [markdown]
# ## GMM

# %%
# Create model project
gmm = GaussianMixture(n_components=2, random_state=123)

# Predict clusters
y_gmm = gmm.fit_predict(X_song_pca)

# Visualize results
plt.scatter(X_song_pca[:, 0], X_song_pca[:, 1], c=y_gmm, s=50, cmap="viridis")
plt.title("GMM Clustering")
plt.show()

# Evaluate results
gmm_silhouette = round(float(metrics.silhouette_score(X_song_pca, y_gmm)), 2)
print(f"The silhouette score of GMM using 2 clusters is {gmm_silhouette}.")
# Out:
# The silhouette score of GMM using 2 clusters is 0.34.

# %% [markdown]
# ## DBSCAN

# %%
# Hyper-parameter tuning
eps_list = np.linspace(0.1, 10, num=100, endpoint=False)
min_samples_list = np.linspace(1, 30, num=30, endpoint=True)

scores = {}
for eps in eps_list:
    for min_samples in min_samples_list:
        dbscan_model = DBSCAN(eps=eps, min_samples=min_samples)
        pred = dbscan_model.fit_predict(X_song_pca)
        key = "eps = {}, MinPts = {}".format(round(eps, 2), round(min_samples, 1))
        try:
            scores[key] = metrics.silhouette_score(X_song_pca, pred)
        except:
            pass

# Show results
max_score = round(float(scores.get(max(scores, key=scores.get))), 2)

print(f"Highest Silhouette score was {max_score} when {max(scores, key=scores.get)}")
# Out:
# Highest Silhouette score was 0.5 when eps = 6.24, MinPts = 1.0

# %%
# Fit with best model
dbscan = DBSCAN(eps=6.24, min_samples=1.0)
y_dbscan = dbscan.fit_predict(X_song_pca)

# Visualize results
plt.scatter(X_song_pca[:, 0], X_song_pca[:, 1], c=y_dbscan, s=50, cmap="viridis")
plt.title("DBSCAN Clustering")
plt.show()

# Evaluate results
dbscan_silhouette = round(float(metrics.silhouette_score(X_song_pca, y_dbscan)), 2)
print(f"The silhouette score of DBSCAN is {dbscan_silhouette}.")
# Out:
# The silhouette score of DBSCAN is 0.5.

# %% [markdown]
# ## HDBSCAN

# %%
# Cluster songs using HDBSCAN
clusterer = hdbscan.HDBSCAN()
y_dbscan = clusterer.fit_predict(X_song_pca)

# %%
# Visualize results
plt.scatter(X_song_pca[:, 0], X_song_pca[:, 1], c=y_dbscan, s=50, cmap="viridis")
plt.title("HDBSCAN Clustering")
plt.show()

# Evaluate results
hdbscan_silhouette = round(float(metrics.silhouette_score(X_song_pca, y_dbscan)), 2)
print(f"The silhouette score of HDBSCAN is {hdbscan_silhouette}.")
# Out:
# The silhouette score of HDBSCAN is -0.1.

# %% [markdown]
# # Dimensionality reduction

# %% [markdown]
# ## PCA

# %%
# Dimension reduction using PCA
word_2dviz.pca_plot(model)

# %% [markdown]
# ## t-SNE

# %%
# Dimension reduction using t-SNE
word_2dviz.tsne_plot(model)

# %% [markdown]
# ## UMAP

# %%
# Dimension reduction using UMAP
word_2dviz.umap_plot(model)

# %% [markdown]
# # Topic modeling

# %% [markdown]
# ## Custom functions

# %%
# Find topics across songs
def lda_model(n_topic, corpus):

    # Run LDA
    ldamodel = gensim.models.LdaMulticore(
        corpus, num_topics=n_topic, id2word=dictionary, passes=10
    )

    # Return model
    return ldamodel

# %%
# Tune the number of topics to maximize coherence
def tune_num_topics(corpus):

    # Try 1 to 10 tipics
    coherence_cv = []
    list_n = list(range(1, 11))

    for n in list_n:
        # LDA model
        model = lda_model(n, corpus)
        # Coherence scores
        coherence_model_lda = CoherenceModel(
            model=model, texts=tokens, dictionary=dictionary, coherence="c_v"
        )
        coherence_cv.append(coherence_model_lda.get_coherence())

    # Plot coherence against num_topics
    plt.figure(figsize=(6, 6))
    plt.plot(list_n, coherence_cv, "-o")
    plt.xlabel(r"Number of topics")
    plt.xticks(np.arange(0, 11, step=1))
    plt.ylabel("Coherence score")
    plt.show()

# %%
# Identify dominant topic of each song
def dominant_topic(ldamodel, corpus, texts):

    topics_df = pd.DataFrame()

    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:
                wp = ldamodel.show_topic(topic_num, topn=4)
                topic_keywords = ", ".join([word for word, prop in wp])
                topics_df = topics_df.append(
                    pd.Series([int(topic_num), round(prop_topic, 4), topic_keywords]),
                    ignore_index=True,
                )
            else:
                break

    topics_df.columns = ["dominant_topic", "perc_contribution", "topic_keywords"]
    contents = pd.Series(texts)
    topics_df = pd.concat([topics_df, contents], axis=1)

    return topics_df

# %%
# Find proportion of each topic in each album
def song_topic(ldamodel, corpus, topic_list):

    # Identify dominant topic of each song
    df_topic = dominant_topic(
        ldamodel=ldamodel, corpus=corpus, texts=df_merged["lyric_lemma"]
    )  # Use "df_merged["lyric_lemma"]"  rather than "tokens" for column title

    # Pull album info
    df_topic = df_topic.merge(df_merged, on="lyric_lemma")

    # Label topics
    topic_num = df_topic["dominant_topic"].unique().tolist()
    df_topic["topic_label"] = df_topic["dominant_topic"].replace(
        dict(zip(topic_num, topic_list))
    )

    # Percentage of each topic in each album
    df_perc = pd.crosstab(df_topic["album_title"], df_topic["topic_label"]).apply(
        lambda row: row / row.sum(), axis=1
    )

    # Reshape data
    df_perc["album"] = df_perc.index

    df_perc_melt = pd.melt(
        df_perc,
        id_vars=["album"],
        value_vars=df_perc.columns[:-1].tolist(),
        var_name="topic",
        value_name="perc",
    )

    return df_perc_melt

# %%
# Visualize topic change over the years
def topic_by_album(df_melt):
    # Sort by album release order
    sorterIndex = dict(zip(studio_albums, range(len(studio_albums))))
    df_melt["album_order"] = df_melt["album"].map(sorterIndex)
    df_melt.sort_values(["album_order"], ascending=True, inplace=True)
    df_melt.drop("album_order", axis=1, inplace=True)

    # Lineplot
    plt.figure(figsize=(10, 5))
    sns.lineplot(x="album", y="perc", hue="topic", data=df_melt, sort=False)
    plt.xlabel("Album")
    plt.xticks(rotation=90)
    plt.ylabel("Proportion")
    plt.legend(bbox_to_anchor=(1.0, 0.9), loc=2, borderaxespad=0.0)
    plt.show()

# %% [markdown]
# ## LDA on bag of words

# %% [markdown]
# ### Hyperparameter tuning
# Resource: https://towardsdatascience.com/evaluate-topic-model-in-python-latent-dirichlet-allocation-lda-7d57484bb5d0

# %%
tune_num_topics(corpus_bow)

# %% [markdown]
# So it's best to use 3 topics.

# %%
# Run LDA on bag of words
ldamodel_bow = lda_model(3, corpus_bow)

# %%
# Show topics
for idx, topic in ldamodel_bow.print_topics(-1):
    print(f"Topic: {idx} \nWords: {topic} \n")
# Out:
# Topic: 0
# Words: 0.065*"come" + 0.040*"dream" + 0.038*"rest" + 0.034*"night" + 0.028*"wish" + 0.026*"home" + 0.025*"deep" + 0.024*"heaven" + 0.024*"angel" + 0.022*"sing"
#
# Topic: 1
# Words: 0.044*"world" + 0.037*"time" + 0.031*"night" + 0.027*"child" + 0.024*"life" + 0.022*"long" + 0.019*"day" + 0.019*"tale" + 0.019*"man" + 0.019*"go"
#
# Topic: 2
# Words: 0.058*"heart" + 0.048*"away" + 0.034*"die" + 0.033*"lie" + 0.023*"great" + 0.023*"world" + 0.022*"tear" + 0.022*"dream" + 0.021*"dead" + 0.020*"live"

# %%
# Visualize results
lda_bow_display = pyLDAvis.gensim.prepare(
    ldamodel_bow, corpus_bow, dictionary, sort_topics=False
)

# lda_bow_display  # In another tab: pyLDAvis.show(lda_bow_display)

# %%
# Topics found in bag of words
topics_bow = ["divinity", "fairytale and fantasy", "innocence"]

# %% [markdown]
# ### Topic change over the years

# %%
# Proportion of each topic in each album
df_bow = song_topic(ldamodel_bow, corpus_bow, topics_bow)

# %%
# Visualize it
topic_by_album(df_bow)

# %% [markdown]
# ## LDA on TF-IDF

# %% [markdown]
# ### Hyperparameter tuning

# %%
tune_num_topics(corpus_tfidf)

# %%
# Run LDA on TF-IDF
ldamodel_tfidf = lda_model(4, corpus_tfidf)

# %%
# Show topics
for idx, topic in ldamodel_tfidf.print_topics(-1):
    print(f"Topic: {idx} \nWords: {topic} \n")
# Out:
# Topic: 0
# Words: 0.045*"heaven" + 0.023*"think" + 0.023*"lord" + 0.020*"death" + 0.020*"away" + 0.017*"star" + 0.016*"child" + 0.014*"feel" + 0.012*"beauty" + 0.011*"world"
#
# Topic: 1
# Words: 0.048*"want" + 0.034*"wonder" + 0.029*"join" + 0.024*"hear" + 0.023*"snow" + 0.022*"angel" + 0.020*"come" + 0.020*"deep" + 0.019*"star" + 0.019*"dance"
#
# Topic: 2
# Words: 0.017*"come" + 0.015*"heart" + 0.015*"soul" + 0.015*"night" + 0.015*"time" + 0.015*"wish" + 0.015*"child" + 0.015*"world" + 0.015*"dream" + 0.014*"earth"
#
# Topic: 3
# Words: 0.029*"land" + 0.025*"sing" + 0.021*"voice" + 0.021*"moment" + 0.017*"need" + 0.017*"man" + 0.016*"word" + 0.016*"begin" + 0.016*"good" + 0.016*"find"

# %%
# Visualize results
lda_tfidf_display = pyLDAvis.gensim.prepare(
    ldamodel_tfidf, corpus_tfidf, dictionary, sort_topics=False
)

# lda_tfidf_display  # In another tab: pyLDAvis.show(lda_tfidf_display)

# %%
# Topics found in TF-IDF
topics_tfidf = ["desire", "fantasy", "divinity", "childhood"]

# %% [markdown]
# ### Topic change over the years

# %%
# Proportion of each topic in each album
df_tfidf = song_topic(ldamodel_tfidf, corpus_tfidf, topics_tfidf)

# Visualize it
topic_by_album(df_tfidf)

# %% [markdown]
# # Summary
